# %% [markdown]
# # Generative Model Evaluation Metrics
#
# This notebook demonstrates how to use the generative metrics library to evaluate generative models.
#
# ## Setup

# %%
import sys
sys.path.insert(0, 'src')

import torch
import matplotlib.pyplot as plt
from generative_metrics import (
    calculate_all_metrics,
    generate_toy_dataset,
    load_dataset,
    create_dataloader,
    set_seed,
    get_device
)

# Set seed for reproducibility
set_seed(42)

# Get device
device = get_device()
print(f"Using device: {device}")
